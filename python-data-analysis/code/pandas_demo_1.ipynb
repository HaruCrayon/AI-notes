# %%
import numpy as np
import pandas as pd

# %%
# 创建一个符合正态分布的10个股票5天的涨跌幅数据
stock_change = np.random.normal(0, 1, (10, 5))

# %%
stock_change
# Out:
# array([[ 0.08381274,  0.6674031 ,  1.46748945, -0.07431339, -0.29399348],
#        [-2.37821199,  0.68750991, -0.18386411, -0.3516686 , -1.40975677],
#        [ 0.40678201, -0.20489392, -0.24586862, -0.69403969,  0.69068959],
#        [-1.1946553 ,  0.05563947,  1.71589331,  0.17138069,  1.45655078],
#        [ 0.11177786,  0.19837482, -1.37200168,  1.84962748,  0.80722562],
#        [ 1.50202973, -0.06030854,  0.82905681,  0.19070872,  0.58592185],
#        [ 0.11845679,  1.06104367,  1.15329126,  0.13542823,  1.61829509],
#        [-0.20283532, -0.89708839,  0.30678304, -0.56636815, -0.13113421],
#        [-1.55105669,  0.02076245, -1.12721109,  0.24802895,  0.68863471],
#        [ 0.06933874, -0.24142083,  0.73297261, -1.21466268, -1.41479932]])

# %%
pd.DataFrame(stock_change)
# Out:
#           0         1         2         3         4
# 0  0.083813  0.667403  1.467489 -0.074313 -0.293993
# 1 -2.378212  0.687510 -0.183864 -0.351669 -1.409757
# 2  0.406782 -0.204894 -0.245869 -0.694040  0.690690
# 3 -1.194655  0.055639  1.715893  0.171381  1.456551
# 4  0.111778  0.198375 -1.372002  1.849627  0.807226
# 5  1.502030 -0.060309  0.829057  0.190709  0.585922
# 6  0.118457  1.061044  1.153291  0.135428  1.618295
# 7 -0.202835 -0.897088  0.306783 -0.566368 -0.131134
# 8 -1.551057  0.020762 -1.127211  0.248029  0.688635
# 9  0.069339 -0.241421  0.732973 -1.214663 -1.414799

# %%
# 添加行索引
stock = ["股票{}".format(i) for i in range(10)]

# %%
stock
# Out:
# ['股票0', '股票1', '股票2', '股票3', '股票4', '股票5', '股票6', '股票7', '股票8', '股票9']

# %%
# 添加列索引
date = pd.date_range(start="20180101", periods=5, freq="B")

# %%
date
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
data = pd.DataFrame(stock_change, index=stock, columns=date)

# %%
data
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0    0.083813    0.667403    1.467489   -0.074313   -0.293993
# 股票1   -2.378212    0.687510   -0.183864   -0.351669   -1.409757
# 股票2    0.406782   -0.204894   -0.245869   -0.694040    0.690690
# 股票3   -1.194655    0.055639    1.715893    0.171381    1.456551
# 股票4    0.111778    0.198375   -1.372002    1.849627    0.807226
# 股票5    1.502030   -0.060309    0.829057    0.190709    0.585922
# 股票6    0.118457    1.061044    1.153291    0.135428    1.618295
# 股票7   -0.202835   -0.897088    0.306783   -0.566368   -0.131134
# 股票8   -1.551057    0.020762   -1.127211    0.248029    0.688635
# 股票9    0.069339   -0.241421    0.732973   -1.214663   -1.414799

# %% [markdown]
# ###  DataFrame的属性和方法

# %%
data.shape
# Out:
# (10, 5)

# %%
data.index
# Out:
# Index(['股票0', '股票1', '股票2', '股票3', '股票4', '股票5', '股票6', '股票7', '股票8', '股票9'], dtype='object')

# %%
data.columns
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
data.values
# Out:
# array([[ 0.08381274,  0.6674031 ,  1.46748945, -0.07431339, -0.29399348],
#        [-2.37821199,  0.68750991, -0.18386411, -0.3516686 , -1.40975677],
#        [ 0.40678201, -0.20489392, -0.24586862, -0.69403969,  0.69068959],
#        [-1.1946553 ,  0.05563947,  1.71589331,  0.17138069,  1.45655078],
#        [ 0.11177786,  0.19837482, -1.37200168,  1.84962748,  0.80722562],
#        [ 1.50202973, -0.06030854,  0.82905681,  0.19070872,  0.58592185],
#        [ 0.11845679,  1.06104367,  1.15329126,  0.13542823,  1.61829509],
#        [-0.20283532, -0.89708839,  0.30678304, -0.56636815, -0.13113421],
#        [-1.55105669,  0.02076245, -1.12721109,  0.24802895,  0.68863471],
#        [ 0.06933874, -0.24142083,  0.73297261, -1.21466268, -1.41479932]])

# %%
data.T
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2018-01-01  0.083813 -2.378212  0.406782 -1.194655  0.111778  1.502030
# 2018-01-02  0.667403  0.687510 -0.204894  0.055639  0.198375 -0.060309
# 2018-01-03  1.467489 -0.183864 -0.245869  1.715893 -1.372002  0.829057
# 2018-01-04 -0.074313 -0.351669 -0.694040  0.171381  1.849627  0.190709
# 2018-01-05 -0.293993 -1.409757  0.690690  1.456551  0.807226  0.585922
#
#                  股票6       股票7       股票8       股票9
# 2018-01-01  0.118457 -0.202835 -1.551057  0.069339
# 2018-01-02  1.061044 -0.897088  0.020762 -0.241421
# 2018-01-03  1.153291  0.306783 -1.127211  0.732973
# 2018-01-04  0.135428 -0.566368  0.248029 -1.214663
# 2018-01-05  1.618295 -0.131134  0.688635 -1.414799

# %%
data.head(3)
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0    0.083813    0.667403    1.467489   -0.074313   -0.293993
# 股票1   -2.378212    0.687510   -0.183864   -0.351669   -1.409757
# 股票2    0.406782   -0.204894   -0.245869   -0.694040    0.690690

# %%
data.tail(2)
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票8   -1.551057    0.020762   -1.127211    0.248029    0.688635
# 股票9    0.069339   -0.241421    0.732973   -1.214663   -1.414799

# %% [markdown]
# ### 修改行列索引值

# %%
# data.index[2] = "股票88" 不能单独修改索引

# %%
stock_ = ["股票_{}".format(i) for i in range(10)]

# %%
data.index = stock_

# %%
data.index
# Out:
# Index(['股票_0', '股票_1', '股票_2', '股票_3', '股票_4', '股票_5', '股票_6', '股票_7', '股票_8',
#        '股票_9'],
#       dtype='object')

# %%
data
# Out:
#       2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票_0    0.083813    0.667403    1.467489   -0.074313   -0.293993
# 股票_1   -2.378212    0.687510   -0.183864   -0.351669   -1.409757
# 股票_2    0.406782   -0.204894   -0.245869   -0.694040    0.690690
# 股票_3   -1.194655    0.055639    1.715893    0.171381    1.456551
# 股票_4    0.111778    0.198375   -1.372002    1.849627    0.807226
# 股票_5    1.502030   -0.060309    0.829057    0.190709    0.585922
# 股票_6    0.118457    1.061044    1.153291    0.135428    1.618295
# 股票_7   -0.202835   -0.897088    0.306783   -0.566368   -0.131134
# 股票_8   -1.551057    0.020762   -1.127211    0.248029    0.688635
# 股票_9    0.069339   -0.241421    0.732973   -1.214663   -1.414799

# %% [markdown]
# ### 重设索引

# %%
data.reset_index(drop=False)
# Out:
#   index  2018-01-01 00:00:00  2018-01-02 00:00:00  2018-01-03 00:00:00  \
# 0  股票_0             0.083813             0.667403             1.467489
# 1  股票_1            -2.378212             0.687510            -0.183864
# 2  股票_2             0.406782            -0.204894            -0.245869
# 3  股票_3            -1.194655             0.055639             1.715893
# 4  股票_4             0.111778             0.198375            -1.372002
# 5  股票_5             1.502030            -0.060309             0.829057
# 6  股票_6             0.118457             1.061044             1.153291
# 7  股票_7            -0.202835            -0.897088             0.306783
# 8  股票_8            -1.551057             0.020762            -1.127211
# 9  股票_9             0.069339            -0.241421             0.732973
#
#    2018-01-04 00:00:00  2018-01-05 00:00:00
# 0            -0.074313            -0.293993
# 1            -0.351669            -1.409757
# 2            -0.694040             0.690690
# ...

# %% [markdown]
# ### 设置新索引

# %%
df = pd.DataFrame({'month': [1, 4, 7, 10],
                    'year': [2012, 2014, 2013, 2014],
                    'sale':[55, 40, 84, 31]})

# %%
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['month', 'year', 'sale'], dtype='object')

# %%
# 以月份设置新的索引
new_df1 = df.set_index("month", drop=True)

# %%
new_df1
# Out:
#        year  sale
# month
# 1      2012    55
# 4      2014    40
# 7      2013    84
# 10     2014    31

# %%
new_df1.index
# Out:
# Index([1, 4, 7, 10], dtype='int64', name='month')

# %%
new_df1.columns
# Out:
# Index(['year', 'sale'], dtype='object')

# %%
# 设置多个索引，以年和月份
new_df2 = df.set_index(["year", "month"])

# %%
new_df2
# Out:
#             sale
# year month
# 2012 1        55
# 2014 4        40
# 2013 7        84
# 2014 10       31

# %%
new_df2.index
# Out:
# MultiIndex([(2012,  1),
#             (2014,  4),
#             (2013,  7),
#             (2014, 10)],
#            names=['year', 'month'])

# %%
new_df2.columns
# Out:
# Index(['sale'], dtype='object')

# %% [markdown]
# ### Series

# %%
data
# Out:
#       2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票_0    0.083813    0.667403    1.467489   -0.074313   -0.293993
# 股票_1   -2.378212    0.687510   -0.183864   -0.351669   -1.409757
# 股票_2    0.406782   -0.204894   -0.245869   -0.694040    0.690690
# 股票_3   -1.194655    0.055639    1.715893    0.171381    1.456551
# 股票_4    0.111778    0.198375   -1.372002    1.849627    0.807226
# 股票_5    1.502030   -0.060309    0.829057    0.190709    0.585922
# 股票_6    0.118457    1.061044    1.153291    0.135428    1.618295
# 股票_7   -0.202835   -0.897088    0.306783   -0.566368   -0.131134
# 股票_8   -1.551057    0.020762   -1.127211    0.248029    0.688635
# 股票_9    0.069339   -0.241421    0.732973   -1.214663   -1.414799

# %%
sr = data.iloc[1, :]

# %%
sr
# Out:
# 2018-01-01   -2.378212
# 2018-01-02    0.687510
# 2018-01-03   -0.183864
# 2018-01-04   -0.351669
# 2018-01-05   -1.409757
# Freq: B, Name: 股票_1, dtype: float64

# %%
sr.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
sr.values
# Out:
# array([-2.37821199,  0.68750991, -0.18386411, -0.3516686 , -1.40975677])

# %%
type(sr.values)
# Out:
# numpy.ndarray

# %%
pd.Series(np.arange(3, 9, 2), index=["a", "b", "c"])
# Out:
# a    3
# b    5
# c    7
# dtype: int32

# %%
pd.Series({'red':100, 'blue':200, 'green': 500, 'yellow':1000})
# Out:
# red        100
# blue       200
# green      500
# yellow    1000
# dtype: int64

# %% [markdown]
# ### 4.2 基本数据操作

# %%
data = pd.read_csv("./datasets/stock_day/stock_day.csv")

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1)

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# ...

# %%
data["open"]["2018-02-26"] # 必须先列后行
# Out:
# 22.8

# %%
data.loc["2018-02-26"]["open"]
# Out:
# 22.8

# %%
data.loc["2018-02-26", "open"]
# Out:
# 22.8

# %%
data.iloc[1, 0]
# Out:
# 22.8

# %%
# 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果
data.loc[data.index[0:4], ['open', 'close', 'high', 'low']]
# Out:
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %%
data.iloc[0:4, data.columns.get_indexer(['open', 'close', 'high', 'low'])]
# Out:
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %% [markdown]
# ### 4.2.2 赋值操作

# %%
data.open
# Out:
# 2018-02-27    23.53
# 2018-02-26    22.80
# 2018-02-23    22.88
# 2018-02-22    22.25
# 2018-02-14    21.49
#               ...
# 2015-03-06    13.17
# 2015-03-05    12.88
# 2015-03-04    12.80
# 2015-03-03    12.52
# 2015-03-02    12.25
# Name: open, Length: 643, dtype: float64

# %%
data["open"]
# Out:
# 2018-02-27    23.53
# 2018-02-26    22.80
# 2018-02-23    22.88
# 2018-02-22    22.25
# 2018-02-14    21.49
#               ...
# 2015-03-06    13.17
# 2015-03-05    12.88
# 2015-03-04    12.80
# 2015-03-03    12.52
# 2015-03-02    12.25
# Name: open, Length: 643, dtype: float64

# %%
data.loc["2018-02-27"]
# Out:
# open               23.53
# high               25.88
# close              24.16
# low                23.53
# volume          95578.03
# price_change        0.63
# p_change            2.68
# turnover            2.39
# Name: 2018-02-27, dtype: float64

# %%
# 整列赋值
data.open = 100

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
data.iloc[1, 0] = 222

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %% [markdown]
# ### 4.2.3 排序

# %%
data.sort_values(by=["high", "p_change"], ascending=False)
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10   100  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12   100  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31   100  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15   100  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11   100  34.98  34.39  32.51  173075.73          0.54      1.59
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-09-07   100  13.38  12.77  12.63   52490.04          0.37      2.98
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# ...

# %%
data.sort_index()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
# ...          ...    ...    ...    ...        ...           ...       ...
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-22   100  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-26   222  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# 2015-03-04      2.30
# ...

# %%
sr = data["price_change"]

# %%
sr.sort_values(ascending=False)
# Out:
# 2015-06-09    3.03
# 2017-10-26    2.68
# 2015-05-21    2.57
# 2017-10-31    2.38
# 2017-06-22    2.36
#               ...
# 2015-07-14   -2.73
# 2015-05-28   -2.80
# 2015-06-19   -3.12
# 2017-11-02   -3.38
# 2015-06-15   -3.52
# Name: price_change, Length: 643, dtype: float64

# %%
sr.sort_index()
# Out:
# 2015-03-02    0.32
# 2015-03-03    0.18
# 2015-03-04    0.20
# 2015-03-05    0.26
# 2015-03-06    1.12
#               ...
# 2018-02-14    0.44
# 2018-02-22    0.36
# 2018-02-23    0.54
# 2018-02-26    0.69
# 2018-02-27    0.63
# Name: price_change, Length: 643, dtype: float64

# %% [markdown]
# ### 4.3.1 算术运算

# %%
data["open"].add(3)
# Out:
# 2018-02-27    103
# 2018-02-26    225
# 2018-02-23    103
# 2018-02-22    103
# 2018-02-14    103
#              ...
# 2015-03-06    103
# 2015-03-05    103
# 2015-03-04    103
# 2015-03-03    103
# 2015-03-02    103
# Name: open, Length: 643, dtype: int64

# %%
data.sub(100)
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27     0 -74.12 -75.84 -76.47   95478.03        -99.37    -97.32
# 2018-02-26   122 -76.22 -76.47 -77.20   60885.11        -99.31    -96.98
# 2018-02-23     0 -76.63 -77.18 -77.29   52814.01        -99.46    -97.58
# 2018-02-22     0 -77.24 -77.72 -77.98   36005.01        -99.64    -98.36
# 2018-02-14     0 -78.01 -78.08 -78.52   23231.04        -99.56    -97.95
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06     0 -85.52 -85.72 -86.87  179731.72        -98.88    -91.49
# 2015-03-05     0 -86.55 -86.84 -87.13   93080.39        -99.74    -97.98
# 2015-03-04     0 -87.08 -87.10 -87.39   66975.44        -99.80    -98.43
# 2015-03-03     0 -86.94 -87.30 -87.48  138971.61        -99.82    -98.56
# 2015-03-02     0 -87.33 -87.48 -87.80   96191.73        -99.68    -97.38
#
#             turnover
# 2018-02-27    -97.61
# 2018-02-26    -98.47
# 2018-02-23    -98.68
# ...

# %%
data["close"].sub(data["open"])
# Out:
# 2018-02-27    -75.84
# 2018-02-26   -198.47
# 2018-02-23    -77.18
# 2018-02-22    -77.72
# 2018-02-14    -78.08
#                ...
# 2015-03-06    -85.72
# 2015-03-05    -86.84
# 2015-03-04    -87.10
# 2015-03-03    -87.30
# 2015-03-02    -87.48
# Length: 643, dtype: float64

# %% [markdown]
# ### 4.3.2 逻辑运算

# %% [markdown]
# - 逻辑运算符号 <、 >、|、 &

# %%
# 筛选p_change > 2的日期数据
data[data["p_change"] > 2]
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63   32445.39          0.82      4.03
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-13   100  14.50  14.47  14.08   61342.22          0.36      2.55
# 2015-03-10   100  14.80  14.65  14.01  101213.51          0.34      2.38
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
# 完成一个多个逻辑判断， 筛选p_change > 2并且low > 15
data[(data["p_change"] > 2) & (data["low"] > 15)]
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63   32445.39          0.82      4.03
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-04-13   100  21.30  21.13  19.50  171822.69          1.70      8.75
# 2015-04-09   100  19.89  19.62  18.02  183119.05          1.20      6.51
# 2015-04-08   100  18.53  18.42  17.60  157725.97          0.88      5.02
# 2015-04-07   100  17.98  17.54  16.50  122471.85          0.88      5.28
# 2015-03-30   100  16.63  16.42  15.99   85090.45          0.65      4.12
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %% [markdown]
# - 逻辑运算函数

# %%
data.query("p_change > 2 & low > 15")
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63   32445.39          0.82      4.03
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-04-13   100  21.30  21.13  19.50  171822.69          1.70      8.75
# 2015-04-09   100  19.89  19.62  18.02  183119.05          1.20      6.51
# 2015-04-08   100  18.53  18.42  17.60  157725.97          0.88      5.02
# 2015-04-07   100  17.98  17.54  16.50  122471.85          0.88      5.28
# 2015-03-30   100  16.63  16.42  15.99   85090.45          0.65      4.12
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
# 判断'turnover'是否为4.19, 2.39
data[data["turnover"].isin([4.19, 2.39])]
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2017-07-25   100  24.20  23.70  22.64  167489.48          0.67      2.91
# 2016-09-28   100  20.98  20.86  19.71   95580.75          0.98      4.93
# 2015-04-07   100  17.98  17.54  16.50  122471.85          0.88      5.28
#
#             turnover
# 2018-02-27      2.39
# 2017-07-25      4.19
# 2016-09-28      2.39
# 2015-04-07      4.19

# %% [markdown]
# ### 4.3.3 统计运算

# %%
data.describe()
# Out:
#              open        high       close         low         volume  \
# count  643.000000  643.000000  643.000000  643.000000     643.000000
# mean   100.189736   21.900513   21.336267   20.771835   99905.519114
# std      4.811210    4.077578    3.942806    3.791968   73879.119354
# min    100.000000   12.670000   12.360000   12.200000    1158.120000
# 25%    100.000000   19.500000   19.045000   18.525000   48533.210000
# 50%    100.000000   21.970000   21.450000   20.980000   83175.930000
# 75%    100.000000   24.065000   23.415000   22.850000  127580.055000
# max    222.000000   36.350000   35.210000   34.010000  501915.410000
#
#        price_change    p_change    turnover
# count    643.000000  643.000000  643.000000
# mean       0.018802    0.190280    2.936190
# std        0.898476    4.079698    2.079375
# min       -3.520000  -10.030000    0.040000
# 25%       -0.390000   -1.850000    1.360000
# 50%        0.050000    0.260000    2.500000
# ...

# %%
data.max(axis=0)
# Out:
# open               222.00
# high                36.35
# close               35.21
# low                 34.01
# volume          501915.41
# price_change         3.03
# p_change            10.03
# turnover            12.56
# dtype: float64

# %%
data.idxmax(axis=0)
# Out:
# open            2018-02-26
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# turnover        2017-10-26
# dtype: object

# %% [markdown]
# ### 4.3.4 累计统计函数

# %%
data["p_change"].sort_index().cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 4.3.5 自定义运算

# %%
data.apply(lambda x: x.max() - x.min())
# Out:
# open               122.00
# high                23.68
# close               22.85
# low                 21.81
# volume          500757.29
# price_change         6.55
# p_change            20.06
# turnover            12.52
# dtype: float64

# %%
data["volume"].max() - data["volume"].min()
# Out:
# 500757.29

# %% [markdown]
# ### 4.4 Pandas画图

# %%
data.plot(x="volume", y="turnover", kind="scatter")
# Out:
# <Axes: xlabel='volume', ylabel='turnover'>

# %%
data.plot(x="high", y="low", kind="scatter")
# Out:
# <Axes: xlabel='high', ylabel='low'>

# %% [markdown]
# ### 4.5.1 读取csv文件

# %%
pd.read_csv("./datasets/stock_day/stock_day.csv", usecols=["high", "low", "open", "close"])
# Out:
#              open   high  close    low
# 2018-02-27  23.53  25.88  24.16  23.53
# 2018-02-26  22.80  23.78  23.53  22.80
# 2018-02-23  22.88  23.37  22.82  22.71
# 2018-02-22  22.25  22.76  22.28  22.02
# 2018-02-14  21.49  21.99  21.92  21.48
# ...           ...    ...    ...    ...
# 2015-03-06  13.17  14.48  14.28  13.13
# 2015-03-05  12.88  13.45  13.16  12.87
# 2015-03-04  12.80  12.92  12.90  12.61
# 2015-03-03  12.52  13.06  12.70  12.52
# 2015-03-02  12.25  12.67  12.52  12.20
#
# [643 rows x 4 columns]

# %%
data = pd.read_csv("./datasets/stock_day/stock_day2.csv", names=["open", "high", "close", "low", "volume", "price_change", "p_change", "ma5", "ma10", "ma20", "v_ma5", "v_ma10", "v_ma20", "turnover"])

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
# 保存'open'列的数据
data[:10].to_csv("test.csv", columns=["open"])

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0   open
# 0  2018-02-27  23.53
# 1  2018-02-26  22.80
# 2  2018-02-23  22.88
# 3  2018-02-22  22.25
# 4  2018-02-14  21.49
# 5  2018-02-13  21.40
# 6  2018-02-12  20.70
# 7  2018-02-09  21.20
# 8  2018-02-08  21.79
# 9  2018-02-07  22.69

# %%
data[:10].to_csv("test.csv", columns=["open"], index=False, mode="w", header=False)

# %% [markdown]
# ### 4.5.2 HDF5

# %%
day_close = pd.read_hdf("./datasets/stock_data/day/day_close.h5")

# %%
day_close.to_hdf("test.h5", key="close")

# %%
pd.read_hdf("test.h5", key="close")
# Out:
#       000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0         16.30      17.71       4.58       2.88      14.60       2.62
# 1         17.02      19.20       4.65       3.02      15.97       2.65
# 2         17.02      17.28       4.56       3.06      14.37       2.63
# 3         16.18      16.97       4.49       2.95      13.10       2.73
# 4         16.95      17.19       4.55       2.99      13.18       2.77
# ...         ...        ...        ...        ...        ...        ...
# 2673      12.96      35.99      22.84       4.37       9.85      16.66
# 2674      13.08      35.84      23.02       4.41       9.85      16.66
# 2675      13.47      35.67      22.40       4.32       9.85      16.66
# 2676      13.40      35.15      22.29       4.29       9.85      16.66
# 2677      13.55      35.55      22.20       4.37       9.85      16.66
#
#       000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# ...

# %%
day_open = pd.read_hdf("./datasets/stock_data/day/day_open.h5")

# %%
day_open.to_hdf("test.h5", key="open")

# %%
pd.read_hdf("test.h5", key="close")
# Out:
#       000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0         16.30      17.71       4.58       2.88      14.60       2.62
# 1         17.02      19.20       4.65       3.02      15.97       2.65
# 2         17.02      17.28       4.56       3.06      14.37       2.63
# 3         16.18      16.97       4.49       2.95      13.10       2.73
# 4         16.95      17.19       4.55       2.99      13.18       2.77
# ...         ...        ...        ...        ...        ...        ...
# 2673      12.96      35.99      22.84       4.37       9.85      16.66
# 2674      13.08      35.84      23.02       4.41       9.85      16.66
# 2675      13.47      35.67      22.40       4.32       9.85      16.66
# 2676      13.40      35.15      22.29       4.29       9.85      16.66
# 2677      13.55      35.55      22.20       4.37       9.85      16.66
#
#       000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# ...

# %% [markdown]
# ### 4.5.3 JSON

# %%
sa = pd.read_json("./datasets/Sarcasm_Headlines_Dataset.json", orient="records", lines=True)

# %%
sa
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
sa.to_json("test.json", orient="records", lines=True)
